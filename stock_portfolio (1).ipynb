# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.32)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.23.5)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.3.10)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2023.11.17)

# %%
import pandas as pd
import datetime
import yfinance as yf

def get_stock(ticker, start_date, end_date):
    data = yf.Ticker(ticker)
    close_prices = data.history(start=start_date, end=end_date)['Close']
    return close_prices

# Example usage
start_date = datetime.datetime(2022, 12, 7)
end_date = datetime.datetime(2023, 12, 7)

tickers = ["SPY", "TSLA", "AAPL", "GOOGL", "AMZN", "MSFT" ]  # Add more tickers as needed

# Create an empty DataFrame to store close prices
df_close_prices = pd.DataFrame()

# Loop through tickers and get close prices
for ticker in tickers:
    close_prices = get_stock(ticker, start_date, end_date)
    df_close_prices[ticker] = close_prices

# Print or use df_close_prices as needed
print(df_close_prices)
# Out:
#                                   SPY        TSLA        AAPL       GOOGL  \
# Date
# 2022-12-07 00:00:00-05:00  387.066711  174.039993  140.156586   94.940002
# 2022-12-08 00:00:00-05:00  390.098969  173.440002  141.857086   93.709999
# 2022-12-09 00:00:00-05:00  387.184845  179.050003  141.369827   92.830002
# 2022-12-12 00:00:00-05:00  392.766998  167.820007  143.686859   93.309998
# 2022-12-13 00:00:00-05:00  395.740204  160.949997  144.661423   95.629997
# ...                               ...         ...         ...         ...
# 2023-11-30 00:00:00-05:00  456.399994  240.080002  189.949997  132.529999
# 2023-12-01 00:00:00-05:00  459.100006  238.830002  191.240005  131.860001
# 2023-12-04 00:00:00-05:00  456.690002  235.580002  189.429993  129.270004
# 2023-12-05 00:00:00-05:00  456.600006  238.720001  193.419998  130.990005
# 2023-12-06 00:00:00-05:00  454.760010  239.369995  192.320007  130.020004
#
#                                  AMZN        MSFT
# Date
# 2022-12-07 00:00:00-05:00   88.459999  242.222229
# 2022-12-08 00:00:00-05:00   90.349998  245.225586
# 2022-12-09 00:00:00-05:00   89.089996  243.263000
# 2022-12-12 00:00:00-05:00   90.550003  250.290680
# 2022-12-13 00:00:00-05:00   92.489998  254.661942
# ...                               ...         ...
# 2023-11-30 00:00:00-05:00  146.089996  378.910004
# 2023-12-01 00:00:00-05:00  147.029999  374.510010
# 2023-12-04 00:00:00-05:00  144.839996  369.140015
# 2023-12-05 00:00:00-05:00  146.880005  372.519989
# 2023-12-06 00:00:00-05:00  144.520004  368.799988
#
# [251 rows x 6 columns]

# %%
df_close_prices
# Out:
#                                   SPY        TSLA        AAPL       GOOGL  \
# Date
# 2022-12-07 00:00:00-05:00  387.066711  174.039993  140.156586   94.940002
# 2022-12-08 00:00:00-05:00  390.098969  173.440002  141.857086   93.709999
# 2022-12-09 00:00:00-05:00  387.184845  179.050003  141.369827   92.830002
# 2022-12-12 00:00:00-05:00  392.766998  167.820007  143.686859   93.309998
# 2022-12-13 00:00:00-05:00  395.740204  160.949997  144.661423   95.629997
# ...                               ...         ...         ...         ...
# 2023-11-30 00:00:00-05:00  456.399994  240.080002  189.949997  132.529999
# 2023-12-01 00:00:00-05:00  459.100006  238.830002  191.240005  131.860001
# 2023-12-04 00:00:00-05:00  456.690002  235.580002  189.429993  129.270004
# 2023-12-05 00:00:00-05:00  456.600006  238.720001  193.419998  130.990005
# 2023-12-06 00:00:00-05:00  454.760010  239.369995  192.320007  130.020004
#
#                                  AMZN        MSFT
# Date
# 2022-12-07 00:00:00-05:00   88.459999  242.222229
# 2022-12-08 00:00:00-05:00   90.349998  245.225586
# 2022-12-09 00:00:00-05:00   89.089996  243.263000
# 2022-12-12 00:00:00-05:00   90.550003  250.290680
# 2022-12-13 00:00:00-05:00   92.489998  254.661942
# ...                               ...         ...
# 2023-11-30 00:00:00-05:00  146.089996  378.910004
# 2023-12-01 00:00:00-05:00  147.029999  374.510010
# 2023-12-04 00:00:00-05:00  144.839996  369.140015
# 2023-12-05 00:00:00-05:00  146.880005  372.519989
# 2023-12-06 00:00:00-05:00  144.520004  368.799988
#
# [251 rows x 6 columns]

# %%
stock_daily_returns = df_close_prices.pct_change().iloc[1:, :]
stock_daily_returns
# Out:
#                                 SPY      TSLA      AAPL     GOOGL      AMZN  \
# Date
# 2022-12-08 00:00:00-05:00  0.007834 -0.003447  0.012133 -0.012956  0.021366
# 2022-12-09 00:00:00-05:00 -0.007470  0.032345 -0.003435 -0.009391 -0.013946
# 2022-12-12 00:00:00-05:00  0.014417 -0.062720  0.016390  0.005171  0.016388
# 2022-12-13 00:00:00-05:00  0.007570 -0.040937  0.006783  0.024863  0.021425
# 2022-12-14 00:00:00-05:00 -0.006394 -0.025784 -0.015536 -0.005856 -0.009839
# ...                             ...       ...       ...       ...       ...
# 2023-11-30 00:00:00-05:00  0.003937 -0.016630  0.003063 -0.018224 -0.001572
# 2023-12-01 00:00:00-05:00  0.005916 -0.005207  0.006791 -0.005055  0.006434
# 2023-12-04 00:00:00-05:00 -0.005249 -0.013608 -0.009465 -0.019642 -0.014895
# 2023-12-05 00:00:00-05:00 -0.000197  0.013329  0.021063  0.013305  0.014085
# 2023-12-06 00:00:00-05:00 -0.004030  0.002723 -0.005687 -0.007405 -0.016068
#
#                                MSFT
# Date
# 2022-12-08 00:00:00-05:00  0.012399
# 2022-12-09 00:00:00-05:00 -0.008003
# 2022-12-12 00:00:00-05:00  0.028889
# 2022-12-13 00:00:00-05:00  0.017465
# 2022-12-14 00:00:00-05:00  0.001168
# ...                             ...
# 2023-11-30 00:00:00-05:00  0.000158
# 2023-12-01 00:00:00-05:00 -0.011612
# 2023-12-04 00:00:00-05:00 -0.014339
# 2023-12-05 00:00:00-05:00  0.009156
# 2023-12-06 00:00:00-05:00 -0.009986
#
# [250 rows x 6 columns]

# %%
import sys
import os
if 'google.colab' in sys.modules:
    # !pip install idaes-pse --pre
    # !idaes get-extensions --to ./bin
    os.environ['PATH'] += ':bin'

from pyomo.environ import *
# Out:
# Collecting idaes-pse
#   Downloading idaes_pse-2.2.0-py3-none-any.whl (46.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 MB 10.3 MB/s eta 0:00:00
# Collecting pyomo>=6.6.2 (from idaes-pse)
#   Downloading Pyomo-6.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 54.0 MB/s eta 0:00:00
# Collecting pint (from idaes-pse)
#   Downloading Pint-0.23-py3-none-any.whl (305 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.0/305.0 kB 29.4 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (3.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (1.23.5)
# Requirement already satisfied: pandas!=2.1.0 in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (1.11.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (1.12)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (3.7.1)
# Requirement already satisfied: click>=8 in /usr/local/lib/python3.10/dist-packages (from idaes-pse) (8.1.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0->idaes-pse) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.0->idaes-pse) (2023.3.post1)
# Collecting ply (from pyomo>=6.6.2->idaes-pse)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->idaes-pse) (3.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pint->idaes-pse) (4.5.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->idaes-pse) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas!=2.1.0->idaes-pse) (1.16.0)
# Installing collected packages: ply, pyomo, pint, idaes-pse
# Successfully installed idaes-pse-2.2.0 pint-0.23 ply-3.11 pyomo-6.7.0
# Getting files...
# Done
# ---------------------------------------------------
# IDAES Extensions Build Versions
# ===================================================
# Solvers:  vno version file found
# Library:  vno version file found
# ===================================================

# %%
from pyomo.environ import *

covariance_matrix = stock_daily_returns.cov()

model = ConcreteModel()
num_stocks = len(tickers) #i
num_days = 250 #j
avg_return_rhs = 0.4

model.x = Var(range(num_stocks), domain=Reals, bounds=(0, None))

model.obj = Objective(
    expr=sum(
        stock_daily_returns.iloc[j, i] * model.x[i] - (sum(stock_daily_returns.iloc[j, i] * model.x[i] for i in range(num_stocks)) / num_days)**2
        for j in range(num_days)
        for i in range(num_stocks)
    ) / num_days,
    sense=minimize,
)

model.c1 = Constraint(expr = sum(model.x[i] for i in range(num_stocks)) == 1)

model.c2 = ConstraintList()
for j in range(num_days):
  model.c2.add = Constraint(expr = sum(stock_daily_returns.iloc[j,i] * model.x[i] for i in range(num_stocks)) >= avg_return_rhs)

solver = SolverFactory('ipopt')
solver.solve(model)
optimal_weights = [f'{value(model.x[i])*100}' for i in range(num_stocks)]
print("Optimal Variance:", model.obj() )
print("Optimal weights:", optimal_weights, )
# Out:
# Optimal Variance: 0.0006818888114569026
# Optimal weights: ['99.99953848115705', '7.165055473582697e-05', '0.00013317963105810172', '0.00011818227628877266', '5.9214292030686694e-05', '7.929208882783765e-05']
